# %% [markdown]
# # **TASK1**

# %% [markdown]
# Suppose your little sibling wants your help to check his math homework. He is done with
# his homework but wants you to see if all his results are correct. Since the student with
# all correct results gets 3 stars. However, you want your brother to check this on his own.
# So, you design a calculator for him in python. You could have given your scientific
# calculator but you wanted to give him a basic calculator and also wanted to see if you
# can even design one.
#
# Subtasks:
# 1. Create a class called Calculator.
# 2. Your class shall have 1 constructor and 4 methods, namely add, subtract,
# multiply and divide.
# 3. Now, create an object of your class. After creating an object, it should print “Let’s
# Calculate!”
# 4. Then take 3 inputs from the user: first value, operator, second value
# 5. Now based on the given operator, call the required method and print the result.
#
# Sample Input:
#
# 1
#
# +
#
# 2
#
# Sample Output:
#
# Let’s Calculate!
#
# Value 1: 1
#
# Operator: +
#
# Value 2: 2
#
# Result: 3

# %%
class Calculator:
    def __init__(self):
        print("Let's Calculate")
        self.first_value=int(input('value 1:'))
        self.operator=input('operator:')
        self.second_value=int(input('value 2:'))

    def add(self):
        print('Result:',(self.first_value)+(self.second_value))
    
    def subtract(self):
        print('Result:',(self.first_value)-(self.second_value))

    def multipy(self):
        print('Result:',(self.first_value)*(self.second_value))

    def divide(self):
        print('Result:',(self.first_value)/(self.second_value))
    
calculator=Calculator()
if calculator.operator=='+':
    calculator.add()
if calculator.operator=='-':
    calculator.subtract()
if calculator.operator=='*':
    calculator.multipy()
if calculator.operator=='/':
    calculator.divide()
# Out:
# Let's Calculate
# value1:1
# operator:+
# value2:2
# Result: 3

# %% [markdown]
# # **Task2**

# %%
class Customer:
    def __init__(self,name):
        self.name=name

    def greet(self,name=None):
        if name!=None:
            print(f'Hello {self.name}!')
        else:
            print('Hello!')

    def purchase(self,*items):
        print(f'{self.name}, you purchase {len(items)} item(s):')
        for i in items:
            print(i)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchase 3 item(s)
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchase 1 item(s)
# orange juice

# %% [markdown]
# # **TASK3**

# %%
class Panda:
    def __init__(self,name,gender,age):
        self.name=name
        self.gender=gender
        self.age=age
 
    def sleep(self,hours=""):
        if hours!="":
            int(hours)
            if hours>=3 and hours<=5:
                return(f'{self.name} sleeps {hours} hours daily and should have Mixed Veggies')
             
            elif hours>=6 and hours<=8:
                return(f'{self.name} sleeps {hours} hours daily and should have Eggplant & Tofu')
            elif hours>=9 and hours<=11:
                return(f'{self.name} sleeps {hours} hours daily and should have Broccoli Chicken')
        else:
           return(f"{self.name}'s duration is unknown thus should have only bamboo leaves")

panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %% [markdown]
# # **TASK4**

# %%
class Cat():
    def __init__(self, color='White', action='sitting'):
         self.color=color
         self.action=action
    
    def printCat(self): 
        print(f'{self.color} cat is {self.action}')
    
    def changeColor(self,color):
        self.color=color


c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %% [markdown]
# # *TASK5***

# %%
class Student():
    def __init__(self,name='default student'):
        self.name=name

    def printdetail(self):
        print(f'Hello {self.name}')     
        print(f'Your average quiz score is {sum(self.num)/3}')     
        
    def quizcalc(self,*num):
        self.num=num
        


s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %% [markdown]
# # **TASK6**

# %%
class Vehicle():
    def __init__(self,x=0,y=0):
        self.x=0
        self.y=0
    
    def print_position(self):
        print(f"({self.x},{self.y})")
    
    def moveUp(self):
        self.y=self.y+1

    def moveLeft(self):
        self.x=self.x-1

    def moveDown(self):
        self.y=self.y-1

    def moveRight(self):
        self.x=self.x+1
        
car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0,0)
# (0,1)
# (-1,1)
# (-1,0)

# %% [markdown]
# # **TASK7**

# %%
class Programmer():
    def __init__(self,name,language,experience):
        self.name=name
        self.language=language
        self.experience=experience
        print('Horray! A new programmer is born')
    
    def printDetails(self):
        print(f'Name:{self.name}')
        print(f'Language:{self.language}')
        print(f'Experience:{self.experience}')
    
    def addExp(self,update):
        self.update=update
        print(f'Updating experience of {self.name}')
        self.experience=self.experience+update

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name:Ethen Hunt
# Language:Java
# Experience:10
# --------------------------
# Horray! A new programmer is born
# Name:James Bond
# Language:C++
# Experience:7
# --------------------------
# Horray! A new programmer is born
# Name:Jon Snow
# Language:Python
# Experience:4
# Updating experience of Jon Snow
# Name:Jon Snow
# Language:Python
# Experience:9

# %% [markdown]
# # **TASK8**

# %%
class Student():
    def __init__(self,name,id,department='CSE'):
        self.name=name
        self.id=id
        self.department=department
  
    def dailyEffort(self,hour):
        self.hour=hour
   
    def printDetails(self):
        print(f'Name:{self.name}')
        print(f'ID:{self.id}')
        print(f'Department:{self.department}')
        print(f'Daily Effort:{self.hour} hours')
        if self.hour<=2:
            print('Suggestion: Should give more effort!')
        elif self.hour<=4:
            print('Suggestion: Keep up the good work!')
        else:
            print('Suggestion: Excellent! Now motivate others.')

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name:Harry Potter
# ID:123
# Department:CSE
# Daily Effort:3 hours
# Suggestion: Keep up the good work!
# ...
# Name:John Wick
# ID:456
# Department:BBA
# Daily Effort:2 hours
# Suggestion: Should give more effort!
# ...
# Name:Naruto Uzumaki
# ID:777
# Department:Ninja
# Daily Effort:6 hours
# Suggestion: Excellent! Now motivate others.

# %% [markdown]
# # **TASK9**

# %%
class Patient():
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
    
    def add_Symptom(self,*symptom):
        self.symptom=symptom
        self.new=''
        for i in range(len(symptom)):
            if i==len(symptom)-1:
                self.new+=symptom[i]
            else:
                self.new+=symptom[i]+','


    def printPatientDetail(self):
        print(f'Name: {self.name}')
        print(f'Age: {self.age}')
        print('Symptoms:',self.new)
 


p1 = Patient('Thomas', 23)
p1.add_Symptom('Headache')
p2 = Patient('Carol', 20)
p2.add_Symptom('Vomiting', 'Coughing')
p3 = Patient('Mike', 25)
p3.add_Symptom('Fever', 'Headache', 'Coughing')
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
print("=========================")
# Out:
# ...
# Name: Thomas
# Age: 23
# Symptoms: Headache
# ...
# Name: Carol
# Age: 20
# Symptoms: Vomiting,Coughing
# ...
# Name: Mike
# Age: 25
# Symptoms: Fever,Headache,Coughing
# ...

# %% [markdown]
# # **TASK10**

# %%
class Avengers():
    def __init__(self,name,partner):
        self.name=name
        self.partner=partner

    def super_powers(self,*powers):
        self.Super_powers=''
        for i in range(len(powers)):
            if i==len(powers)-1:
                self.Super_powers+=powers[i]
            else:
                self.Super_powers+=powers[i]+','

    def printAvengersDetail(self):
        print(f'Name:{self.name}')
        print(f'Partner:{self.partner}')
        print(f'Super powers:{self.Super_powers}')


a1 = Avengers('Captain America', 'Bucky Barnes')
a1.super_powers('Stamina', 'Slowed ageing')
a2 = Avengers('Doctor Strange', 'Ancient One')
a2.super_powers('Mastery of magic')
a3 = Avengers('Iron Man', 'War Machine')
a3.super_powers('Genius level intellect', 'Scientist ')
print("=========================")
a1.printAvengersDetail()
print("=========================")
a2.printAvengersDetail()
print("=========================")
a3.printAvengersDetail()
print("=========================")
# Out:
# ...
# Name:Captain America
# Partner:Bucky Barnes
# Super powers:Stamina,Slowed ageing
# ...
# Name:Doctor Strange
# Partner:Ancient One
# Super powers:Mastery of magic
# ...
# Name:Iron Man
# Partner:War Machine
# Super powers:Genius level intellect,Scientist
# ...

# %% [markdown]
# # **TASK11**

# %%
class Shinobi():
    def __init__(self,name,rank,salary=0):
        self.name=name
        self.rank=rank
        self.mission=0
        self.salary=salary

    def calSalary(self,mission):
        self.mission=mission
        if self.rank=='Genin':
            self.salary=mission*50
        elif self.rank=="Chunin":
            self.salary=mission*100
        else:
            self.salary=mission*500

    def printInfo(self):
        print(f'Name: {self.name}')
        print(f'Rank: {self.rank}')
        print(f'Number of mission: {self.mission}')
        print(f'Salary:{self.salary}')

    def changeRank(self,Rank):
        self.rank=Rank


naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary:250
# ...
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary:0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary:1000
# ...
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary:2500

# %% [markdown]
# # **TASK12**

# %%
class ParcelKoro():
    def __init__(self,name="No name set",weight=0,total_fee=0):
        self.name=name
        self.product_weight=weight
        self.total_fee=total_fee
        
    def calculateFee(self,location=None):
        self.location=location
        if location==None:
            location_charge=50
        else:
            location_charge=100
        self.total_fee = (self.product_weight * 20) + location_charge

    def printDetails(self):
        print('Customer Name:',self.name)
        print('Product Weight:',self.product_weight)
        if self.product_weight==0:
            print('Total fee: 0')
        else:
            print('Total fee:',self.total_fee)

            
        

print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 15
# Total fee: 350
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %% [markdown]
# # **TASK13**

# %%
class Batsman():
    def __init__(self,*info):
        if len(info)==3:
            self.name=info[0]
            self.runs=info[1]
            self.balls=info[2]
        elif len(info)==2:
            self.name='New Batsman'
            self.runs=info[0]
            self.balls=info[1]
    
    def setName(self,name):
        self.name=name

    def battingStrikeRate(self):
        return((self.runs/ self.balls )*100)
    
    def printCareerStatistics(self):
        print('Name:' ,self.name)
        print('Runs Scored:',self.runs ,',' 'Balls Faced:',self.balls)


b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101 ,Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678 ,Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101 ,Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %% [markdown]
# # **TASK14**

# %%
class EPL_Team():
    def __init__(self,name,song='No Slogan',title=0):
        self.name=name
        self.song=song
        self.title=title

    def showClubInfo(self):
         result='Name:'+self.name+'\n'+'Song:'+self.song+'\n'+'title:'+str(self.title)
         return(result)
    
    def changeSong(self,song):
        self.song=song

    def increaseTitle(self):
        self.title+=1


manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name:Manchester United
# Song:Glory Glory Man United
# title:0
# ##################
# Name:Manchester United
# Song:Glory Glory Man United
# title:1
# ...
# Name:Chelsea
# Song:No Slogan
# title:0
# Name:Chelsea
# Song:Keep the blue flag flying high
# title:0

# %% [markdown]
# # **TASK15**

# %%
class Account():
    def __init__(self,name='Default Account',balance=0.0):
        self.name=name
        self.balance=balance
    
    def details(self):
       result=self.name+'\n'+str(self.balance)
       return(result)
    
    def withdraw(self,withdraw):
        if self.balance<withdraw or withdraw>6929:
            print('Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.')
        else:
            print(f'Withdraw successful! New balance is {self.balance-withdraw }')
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930);
print("------------------------")
a2.withdraw(600);
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is 3071.0

# %% [markdown]
# # **TASSK16**

# %%
class Author():
    def __init__(self,name='Default',*books):
        self.name=name
        self.books=books
    
    def addBooks(self,*books):
        self.books=books
    
    def changeName(self,name):
        self.name=name
    
    def printDetails(self):
        print('Author Name:',self.name)
        print('--------')
        print('List of Books:')
        for i in self.books:
            print(i)
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print('===================')
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print('===================')
auth2.printDetails()
print('===================')
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %% [markdown]
# # **Task21**

# %%
class Hospital():
    def __init__(self,name):
        self.name=name
        self.doctor={}          #faka cz different class
        self.patient={}
        self.no_of_doc=0
        self.no_of_pat=0

    def addDoctor(self,dic):
        doc=dic.doctor          #d1.doctor (d1 object er modhe je doctor dictionary ta ase)
        print(doc)
        for id in doc:
            self.doctor[id]=doc[id]         #hospital class er dictionary doctor er ke Doctor class er dictionary banailam
            self.no_of_doc+=1

    def getDoctorByID(self,id):
        doc=self.doctor[id]          #just key er value access kore
        print(doc)
        result='Doctor\'s ID: '+id+'\nName: '+doc[0]+'\nSpeciality:'+doc[1]
        return(result)

    def addPatient(self,dic):
        pat=dic.patient
        for id in pat:
            self.patient[id]=pat[id]
            self.no_of_pat+=1
  
    def getPatientByID(self,id):
        pat=self.patient[id]
        result='Patient\'s ID:'+id+'\nName: '+pat[0]+'\nage:'+str(pat[1])+ '\nPhone no:'+str(pat[2])
        return(result)

    def allDoctors(self):
        print('All Doctors:')
        print('Num of doctors:',self.no_of_doc)
        print(self.doctor)

    def allPatients(self):
        print('All Patients:')
        print('Num of patients:',self.no_of_pat)
        print(self.patient)


class Doctor():
    def __init__(self,id,pro,name,spec):
        self.doctor={}
        self.doctor[id]=[name,spec]

class Patient():
    def __init__(self,id,pro,name,age,phone):
        self.patient={}
        self.patient[id]=[name,age,phone]

h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# {'1d': ['Samar Kumar', 'Neurologist']}
# ...
# ['Samar Kumar', 'Neurologist']
# Doctor's ID: 1d
# Name: Samar Kumar
# Speciality:Neurologist
# ...
# Patient's ID:1p
# Name: Kashem Ahmed
# age:35
# Phone no:12345
# ...
# Patient's ID:2p
# Name: Tanina Haque
# age:26
# Phone no:33456
# ...
# All Doctors:
# Num of doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Num of patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
#20
class Author():
    def __init__(self,name=None,num=0):
        self.name=name
        self.num=num
        self.l={}
        
    def addBook(self,book,catagory):
        self.book=book
        self.catagory=catagory
        if self.name==None:
            print('a book cant be added without author\'s name')
        else:
            self.num+=1
            if catagory not in self.l:
                self.l[catagory]=[book]
            else:
                self.l[catagory].append(book)

            
    def setName(self,name):
        self.name=name
    def printDetail(self):
        print('Number of books',self.num)
        print('Name:',self.name)
        for k,v in self.l.items():
            s=''
            for i in range(len(v)):
                if i==len(v)-1:
                    s+=v[i]
                else:
                   s+=v[i]+','
            print(k,':',s)
          
a1 = Author()
print("=================================")
a1.addBook('Ice', 'Science Fiction')
print("=================================")
a1.setName('Anna Kavan')
a1.addBook('Ice', 'Science Fiction')
a1.printDetail()
print("=================================")
a2 = Author('Humayun Ahmed')
a2.addBook('Onnobhubon', 'Science Fiction')
a2.addBook('Megher Upor Bari', 'Horror')
print('=================================')
a2.printDetail()
a2.addBook('Ireena', 'Science Fiction')
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# a book cant be added without author's name
# ...
# Number of books 1
# Name: Anna Kavan
# Science Fiction : Ice
# ...
# Number of books 2
# Name: Humayun Ahmed
# Science Fiction : Onnobhubon
# Horror : Megher Upor Bari
# ...
# Number of books 3
# Name: Humayun Ahmed
# Science Fiction : Onnobhubon,Ireena
# Horror : Megher Upor Bari
# ...

# %%
#17
class Student:
    def __init__(self,name=None,dep=None):
        self.name=name
        self.dep=dep
        if name==None and dep==None:
            print('Student name and department need to be set')
        elif name!=None and dep==None:
            print(f'Department for {name} need to be set')
        else:
            print(f'{name} is from {dep}')

    def update_name(self,name):
        self.name=name
    def update_department(self,dep):
        self.dep=dep
    def enroll(self,*sub):
        self.sub=sub
    def printDetail(self):
        print(f'Name:{self.name}')
        print(f'Department:{self.dep}')
        print(f'{self.name} enrolled in {len(self.sub)} courses')
        for i in self.sub:
            print(i,end=" ")

s1 = Student()
print('=========================')
s2 = Student('Carol')
print('=========================')
s3 = Student('Jon', 'EEE')
print('=========================')
s1.update_name('Bob')
s1.update_department('CSE')
s2.update_department('BBA')
s1.enroll('CSE110', 'MAT110', 'ENG091')
s2.enroll('BUS101')
s3.enroll('MAT110', 'PHY111')
print('###########################')
s1.printDetail()
print('=========================')
s2.printDetail()
print('=========================')
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol need to be set
# ...
# Jon is from EEE
# ...
# ###########################
# Name:Bob
# Department:CSE
# Bob enrolled in 3 courses
# CSE110 MAT110 ENG091 =========================
# Name:Carol
# Department:BBA
# Carol enrolled in 1 courses
# BUS101 =========================
# Name:Jon
# Department:EEE
# Jon enrolled in 2 courses
# MAT110 PHY111

# %%
#18
class Student:
    def __init__(self,name,id,dep):
        self.n=name
        self.id=id
        self.d=dep
    def details(self):
        x=f'Name:{self.n} \nID:{self.id} \nDEpartment:{self.d}'
        return x
    def advise(self,*sub):
        self.sub=sub
        print(f'{self.n},you have taken{len(sub)*3}credits ')
        print('List of courses:',end='')
        for i in range(len(sub)):
            if i==len(sub)-1:
                print(sub[i])
            else:
                print(sub[i],end=',')
        if len(sub)!=4:
            if len(sub)>4:
                print(f'Status: You have to drop at least {len(sub)-4} course.')
            else:
                print(f'Status: You have to take at least {4-len(sub)} course.')
        else:
            print('Status: ok.')
s1 = Student('Alice','20103012','CSE')
s2 = Student('Bob', '18301254','EEE')
s3 = Student('Carol', '17101238','CSE')
print('##########################')
print(s1.details())
print('##########################')
print(s2.details())
print('##########################')
s1.advise('CSE110', 'MAT110', 'PHY111')
print('##########################')
s2.advise('BUS101', 'MAT120')
print('##########################')
s3.advise('MAT110', 'PHY111', 'ENG102','CSE111', 'CSE230')
# Out:
# ##########################
# Name:Alice
# ID:20103012
# DEpartment:CSE
# ##########################
# Name:Bob
# ID:18301254
# DEpartment:EEE
# ##########################
# Alice,you have taken9credits
# List of courses:CSE110,MAT110,PHY111
# Status: You have to take at least 1 course.
# ##########################
# Bob,you have taken6credits
# List of courses:BUS101,MAT120
# Status: You have to take at least 2 course.
# ##########################
# Carol,you have taken15credits
# List of courses:MAT110,PHY111,ENG102,CSE111,CSE230
# Status: You have to drop at least 1 course.

# %%
class Hotel():
        
        #intialising variables
        def __init__(self,name):
                self.name=name
                self.staff={}
                self.guest={}
        
        
        #defining functions
        
        def addStuff(self,staf,age,phone="000"):
            self.age=age
            self.staf=staf
            self.phone=phone
            self.staff[len(self.staff)+1]=(staf,age,phone)
            print("Staff With ID {} is created".format(len(self.staff)))

        def getStuffById(self,id):
            self.id=id
            result='Staff ID:'+str(id)+'\nName:'+self.staf+"\nAge:"+str(self.age)+'\nPhone no:'+self.phone
            return(result)
        
        def allStaffs(self):
                print("All Staffs:")
                print("Number of Staff: ",len(self.staff))

                data=self.staff
                print(data)
                for i in data:
                    print(i)
                    print("Staff ID: {} Name: {} Age: {} Phone no: {}".format(i,data[i][0],data[i][1],data[i][2]))
                return ''
        
        def addGuest(self,guest1,age,phone="000"):
            self.age=age
            self.guest1=guest1
            self.phone=phone
            self.guest[len(self.guest)+1]=(guest1,age,phone)
            print("Guest With ID {} is created".format(len(self.guest)))
        def getGuestById(self,id):
            self.id=id  
            result='Staff ID:'+str(id)+'\nName:'+self.guest1+"\nAge:"+str(self.age)+'\nPhone no:'+str(self.phone)
            return(result)
        
        def allGuest(self):
                print("All Guest:")
                print("Number of Guest: ",len(self.guest))
                data=self.guest
                for i in data:
                        print("Guest ID: {} Name: {} Age: {} Phone no: {}".format(i,data[i][0],data[i][1],data[i][2]))
                return ''
                
                
        
                
# Do not change the following lines of code.
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest('Carol',35,'123')
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, '431')
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff With ID 1 is created
# ...
# Staff ID:1
# Name:Adam
# Age:26
# Phone no:000
# ...
# Guest With ID 1 is created
# ...
# Staff ID:1
# Name:Carol
# Age:35
# Phone no:123
# ...
# Guest With ID 2 is created
# ...
# Staff ID:2
# Name:Diana
# Age:32
# Phone no:431
# ...
# All Staffs:
# Number of Staff:  1
# {1: ('Adam', 26, '000')}
# 1
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# ...
# All Guest:
# Number of Guest:  2
# Guest ID: 1 Name: Carol Age: 35 Phone no: 123
# Guest ID: 2 Name: Diana Age: 32 Phone no: 431
# ''
