# %%
#task1
class Marks():
    def __init__(self,mark):
        self.mark=mark

        
    def __add__(self,other):
        total=Marks(self.mark+other.mark)

        return(total)





Q1 = Marks(int(input("Quiz 1 (out of 10): ")))
Q2 = Marks(int(input("Quiz 2 (out of 10): ")))
Lab = Marks(int(input("Lab (out of 30): ")))
Mid = Marks(int(input("Mid (out of 20): ")))
Final = Marks(int(input("Final (out of 30): ")))
total = Q1 + Q2 + Lab + Mid + Final
print("Total marks: {}".format(total.mark))
# Out:
# Quiz 1 (out of 10): 10
# Quiz 2 (out of 10): 10
# Lab (out of 30): 8
# Mid (out of 20): 29
# Final (out of 30): 40
# Total marks: 97

# %%
#task2
class Teacher():
    def __init__(self,name,department):
        self.__name=name
        self.__department=department
        self.__l1=[]
    def addCourse(self,course):
        
        self.__l1.append(course.course) # here course=c2/c3 location 
        print(course)
        print(course.course)
    def printDetail(self):
        print("====================================")
        print(f'Name:{self.__name}')
        print(f'Department:{self.__department}')
        print('List of courses')
        print("====================================")
        for i in self.__l1:
            print(i)
        print("====================================")
        
class Course():
    def __init__(self,course):
        self.course=course

t1 = Teacher("Saad Abdullah", "CSE")
t2 = Teacher("Mumit Khan", "CSE")
t3 = Teacher("Sadia Kazi", "CSE")
c1 = Course("CSE 110 Programming Language I")
c2 = Course("CSE 111 Programming Language-II")
c3 = Course("CSE 220 Data Structures")
c4 = Course("CSE 221 Algorithms")
c5 = Course("CCSE 230 Discrete Mathematics")
c6 = Course("CSE 310 Object OrientedProgramming")
c7 = Course("CSE 320 Data Communications")
c8 = Course("CSE 340 Computer Architecture")
t1.addCourse(c1)
t1.addCourse(c2)
t2.addCourse(c3)
t2.addCourse(c4)
t2.addCourse(c5)
t3.addCourse(c6)
t3.addCourse(c7)
t3.addCourse(c8)
t1.printDetail()
t2.printDetail()
t3.printDetail()
# Out:
# ...
# CSE 110 Programming Language I
# ...
# CSE 111 Programming Language-II
# ...
# CSE 220 Data Structures
# ...
# CSE 221 Algorithms
# ...
# CCSE 230 Discrete Mathematics
# ...
# CSE 310 Object OrientedProgramming
# ...
# CSE 320 Data Communications
# ...
# CSE 340 Computer Architecture
# ...
# Name:Saad Abdullah
# Department:CSE
# List of courses
# ...
# CSE 110 Programming Language I
# CSE 111 Programming Language-II
# ...
# Name:Mumit Khan
# Department:CSE
# List of courses
# ...
# CSE 220 Data Structures
# CSE 221 Algorithms
# CCSE 230 Discrete Mathematics
# ...
# Name:Sadia Kazi
# Department:CSE
# List of courses
# ...
# CSE 310 Object OrientedProgramming
# CSE 320 Data Communications
# CSE 340 Computer Architecture
# ...

# %%
#task3
class Team():
    def __init__(self,team=''):
        self.__team=team
        self.__l1=[]
    def setName(self,team):
        #if self.__team=='':
            self.__team=team
    def addPlayer(self,name):
        
        self.__l1.append(name.name)
    def printDetail(self):
        print("=====================")
        print(f'Team: {self.__team}')
        print("List of Players:")
        print(self.__l1)
        print("=====================")


class Player():
    def __init__(self,name):
        self.name=name

b = Team()
b.setName('Bangladesh')
mashrafi = Player("Mashrafi")
b.addPlayer(mashrafi)
tamim = Player("Tamim")
b.addPlayer(tamim)
b.printDetail()
a = Team("Australia")
ponting = Player("Ponting")
a.addPlayer(ponting)
lee = Player("Lee")
a.addPlayer(lee)
a.printDetail()
# Out:
# ...
# Team: Bangladesh
# List of Players:
# ['Mashrafi', 'Tamim']
# ...
# Team: Australia
# List of Players:
# ['Ponting', 'Lee']
# ...

# %%
#Task4
class Color():
    def __init__(self,clr):
        self.clr=clr
    def __add__(self,other):
        if (self.clr=="red" and other.clr=="yellow")or(other.clr=="red" and self.clr=="yellow"):
             self.clr="Orange"
        elif(self.clr=="red" and other.clr=="blue")or(other.clr=="red" and self.clr=="blue"):
            self.clr="Violet"   
        elif (self.clr=="blue" and other.clr=="yellow")or(other.clr=="blue" and self.clr=="yellow"):
            self.clr="Green"
        c3=Color(self.clr)  #c3 ekta location
        return(c3)

C1 = Color(input("First Color: ").lower())
C2 = Color(input("Second Color: ").lower())
C3 = C1 + C2
print("Color formed:", C3.clr) #value
# Out:
# First Color: blue
# Second Color: red
# Color formed: Violet

# %%
#task5
class Circle:
    def __init__(self,radius):
        self.__radius=radius
    
    def area(self):
        import math
        return(math.pi *self.__radius**2)
    def __add__(self,other):
        self.__radius=self.__radius+other.__radius
        c3=Circle(self.__radius)
        return(c3)
    def getRadius(self):
        return(self.__radius)


c1 = Circle(4)
print("First circle radius:" , c1.getRadius())
print("First circle area:" ,c1.area())
c2 = Circle(5)
print("Second circle radius:" ,c2.getRadius())
print("Second circle area:" ,c2.area())
c3 = c1 + c2
print("Third circle radius:" ,c3.getRadius())
print("Third circle area:" ,c3.area())
# Out:
# First circle radius: 4
# First circle area: 50.26548245743669
# Second circle radius: 5
# Second circle area: 78.53981633974483
# Third circle radius: 9
# Third circle area: 254.46900494077323

# %%
#Task6
class Triangle:
    def __init__(self,first,second):
        self.__first=first
        self.__second=second
    def getBase(self):
        return(self.__first)
    def getHeight(self):
        return(self.__second)
    def area(self):
        return(self.__first*self.__second*.5)
    def __sub__(self,other):
        self.__first=self.__first-other.__first
        self.__second=self.__second-other.__second
        t3=Triangle(self.__first,self.__second)
        return(t3)


t1 = Triangle(10, 5)
print("First Triangle Base:" , t1.getBase())
print("First Triangle Height:" , t1.getHeight())
print("First Triangle area:" ,t1.area())
t2 = Triangle(5, 3)
print("Second Triangle Base:" , t2.getBase())
print("Second Triangle Height:" , t2.getHeight())
print("Second Triangle area:" ,t2.area())
t3 = t1 - t2
print("Third Triangle Base:" , t3.getBase())
print("Third Triangle Height:" , t3.getHeight())
print("Third Triangle area:" ,t3.area())
# Out:
# First Triangle Base: 10
# First Triangle Height: 5
# First Triangle area: 25.0
# Second Triangle Base: 5
# Second Triangle Height: 3
# Second Triangle area: 7.5
# Third Triangle Base: 5
# Third Triangle Height: 2
# Third Triangle area: 5.0

# %%
#task7
class Dolls:
    def __init__(self,doll,price):
        self.doll=doll
        self.price=price
    def detail(self):
        result="Doll:" +self.doll+ "\nTotal Price:" +str(self.price)
        return(result)
    def __gt__(self,other):
        if self.price>other.price:
            return True
        else:
            return False
    def __add__(self,other):
        self.doll=self.doll+" "+ other.doll
        self.price=int(self.price)+int(other.price)
        obj5=Dolls(self.doll,self.price)
        return(obj5)


obj_1 = Dolls("Tweety", 2500)
print(obj_1.detail())
if obj_1 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")
    print("=========================")
obj_2 = Dolls("Daffy Duck", 1800)
print(obj_2.detail())
if obj_2 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")
print("=========================")
obj_3 = Dolls("Bugs Bunny", 3000)
print(obj_3.detail())
if obj_3 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")
print("=========================")
obj_4 = Dolls("Porky Pig", 1500)
print(obj_4.detail())
if obj_4 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")
print("=========================")
obj_5 = obj_2 + obj_3
print(obj_5.detail())
if obj_5 > obj_1:
    print("Congratulations! You get the Tweety as a gift!")
else:
    print("Thank you!")
# Out:
# Doll:Tweety
# Total Price:2500
# Thank you!
# ...
# Doll:Daffy Duck
# Total Price:1800
# Thank you!
# ...
# Doll:Bugs Bunny
# Total Price:3000
# Congratulations! You get the Tweety as a gift!
# ...
# Doll:Porky Pig
# Total Price:1500
# Thank you!
# ...
# Doll:Daffy Duck Bugs Bunny
# Total Price:4800
# Congratulations! You get the Tweety as a gift!

# %%
#Task8
class Coordinates():
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2
    def __sub__(self,other):
        print(other.num2)
        num2 = self.num2 - other.num2
        num1 = self.num1 - other.num1
        p4 = Coordinates(num1, num2)
        return p4
    def __mul__(self,other):
        num2 = self.num2 * other.num2
        num1 = self.num1 * other.num1
        p6 = Coordinates(num1, num2)
        return p6
    def __eq__(self,other):
        if self.num1==other.num1 and self.num2==other.num2:
            return "The calculated coordinates are the same."
        else:
            return "The calculated coordinates are NOT the same"
    def detail(self):
        x=self.num1,self.num2
        return x





p1 = Coordinates(int(input()),int(input()))
p2 = Coordinates(int(input()),int(input()))
p4 = p1 - p2
print(p4.detail())
p5 = p1 * p2
print(p5.detail())
point_check = (p4 == p5)
print(point_check)
# Out:
# 0
# 0
# 0
# 0
# 0
# (0, 0, 5)
# (0, 0, 5)
# The calculated coordinates are the same.
